# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
# %matplotlib inline

# %%
instances = pd.read_csv('data/instances.csv')

# %%
time_options = [6, 12, 24, 72, 142,284,568,1136, 2272]
time = time_options[8]
excluded_instances = [
    'mastodon.social',
    'mastodon.lol',
    'mastodon.online',
    'mstdn.ca',
    'pawoo.net',
    'mstdn.jp',
    'mastodon.uno',
    'mastodon.nl'
]

# %%
instances = instances[~instances['name'].isin(excluded_instances)]

# %%
# filter the top 20
limit = min(sorted(instances[str(time)].tolist(), reverse=True)[:20])
instances = instances[instances[str(time)] >= limit]

# %%
fig = px.bar(instances, y='name', x=str(time))
fig.show()

# %%
# Out:
# /usr/bin/python
