# %%
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
# %matplotlib inline

# %%
instances = pd.read_csv('data/instances.csv')

# %%
time_options = [6, 12, 24, 72, 142,284,568,1136, 2272]
time = time_options[8]
excluded_instances = [
    'mastodon.social',
    'mastodon.lol',
    'mastodon.online',
    'mstdn.ca',
    'pawoo.net',
    'mstdn.jp',
    'mastodon.uno',
    'mastodon.nl'
]

# %%
# filter the top 20
limit = min(sorted(instances[str(time)].tolist(), reverse=True)[:20])
instances = instances[instances[str(time)] >= limit]

# %%
instances[~instances['name'].isin(excluded_instances)]
# Out:
#                 name     users   statuses      6     12     24     72     142  \
# 4       mstdn.social  175125.0  7817357.0  102.0  154.0  343.0  915.0  1943.0
# 6     counter.social  165119.0  9430659.0   13.0   18.0   33.0   88.0   203.0
# 7             mas.to  148550.0  2827463.0   34.0   81.0  165.0  437.0   931.0
# 8     mastodon.world  146164.0  1400507.0   66.0   98.0  216.0  528.0  1340.0
# 10   pixelfed.social   71492.0   491757.0    0.0    0.0    1.0   52.0   233.0
# 11  mastodon.sdf.org   71196.0   788768.0    9.0   15.0   37.0   83.0   189.0
# 17              c.im   61789.0   903092.0    1.0    1.0    5.0   24.0    68.0
# 19  brighteon.social   48797.0  2318144.0   37.0   45.0   48.0   61.0    87.0
# 22  infosec.exchange   44804.0   761178.0   52.0   86.0  192.0  552.0  1510.0
# 25       sfba.social   36874.0   507101.0    6.0   11.0   29.0  115.0   258.0
# 31     mindly.social   33730.0   415489.0   15.0   29.0   51.0  136.0   309.0
# 37    toot.community   28114.0   488210.0   10.0   17.0   32.0   72.0   157.0
#
#        284      568      1136      2272
# 4   4545.0  22664.0  136132.0  136132.0
# 6    544.0   2845.0  158844.0  158844.0
# 7   2863.0  15426.0   36578.0  110069.0
# 8   3037.0  21902.0  117433.0  144943.0
# 10   449.0  59174.0    7832.0   59174.0
# 11   423.0  23590.0   48075.0   48075.0
# 17   152.0    865.0    5616.0   45375.0
# 19   112.0    177.0   48554.0   48554.0
# 22  2737.0   9643.0   20553.0   39734.0
# 25   592.0   4197.0   14238.0   32709.0
# 31   759.0   6918.0   15365.0   33692.0
# 37   406.0   2836.0   10506.0   28055.0

# %%
fig = px.bar(instances, y='name', x=str(time))
fig.show()

# %%
# Out:
# /usr/bin/python
